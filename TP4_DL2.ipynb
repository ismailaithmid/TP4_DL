# %%
import os
import pandas as pd
import numpy as np
import cv2
from sklearn . model_selection import train_test_split
from sklearn . preprocessing import LabelEncoder , OneHotEncoder
from sklearn . metrics import confusion_matrix ,classification_report
import matplotlib . pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold
# Fonctions d’activation
def relu (x ):
    """
    ReLU activation : max (0 , x)
    """
    assert isinstance (x , np . ndarray ) , " Input to ReLU must be a numpy array "
    result = np . maximum (0 , x)
    assert np . all ( result >= 0) , " ReLU output must be non - negative "
    return result

def relu_derivative ( x) :
    """
    Derivative of ReLU : 1 if x > 0 , else 0
    """
    assert isinstance (x , np . ndarray ) , " Input to ReLU derivative must be a numpy array "
    result = np . where (x > 0 , 1 , 0)
    assert np . all (( result == 0) | ( result == 1) ) , " ReLU derivativemust be 0 or 1"
    return result
    
def softmax ( x):
    """
    Softmax activation : exp (x) / sum ( exp (x))
    """
    assert isinstance (x , np . ndarray ) , " Input to softmax must be a numpy array "
    exp_x = np . exp ( x - np . max ( x , axis =1 , keepdims = True ))

    result = exp_x / np .sum ( exp_x , axis =1 , keepdims = True )
    assert np . all (( result >= 0) & ( result <= 1) ) , " Softmax output must be in [0 , 1]"
    
    assert np . allclose ( np .sum ( result , axis =1) , 1) , " Softmax output sum to 1 per sample "
    
    return result

# %%
# Classe MultiClassNeuralNetwork
class MultiClassNeuralNetwork:
    def __init__(self , layer_sizes , model_optimization,learning_rate =0.01):
        """
        Initialize the neural network with given layer sizes and
        learning rate.
        layer_sizes: List of integers [input_size , hidden1_size ,
        ..., output_size]
        """
        assert isinstance(layer_sizes , list) and len(layer_sizes)>= 2, "layer_sizes must be a list with at least 2elements"
        assert all(isinstance(size , int) and size > 0 for size in layer_sizes), "All layer sizes must be positive integers"
        assert isinstance(learning_rate , (int , float)) and learning_rate > 0, "Learning rate must be a positivenumber"

        self.layer_sizes = layer_sizes
        self.learning_rate = learning_rate
        self.weights = []
        self.biases = []
        self.model_optimization=model_optimization


        # Initialisation des poids et biais
        np.random.seed (42)
        for i in range(len(layer_sizes) - 1):
            w = np.random.randn(layer_sizes[i], layer_sizes[i+1])* 0.01
            b = np.zeros((1, layer_sizes[i+1]))
            assert w.shape == (layer_sizes[i], layer_sizes[i+1]),f"Weight matrix {i+1} has incorrect shape"
            assert b.shape == (1, layer_sizes[i+1]), f"Bias vector{i+1} has incorrect shape"
            self.weights.append(w)
            self.biases.append(b)
            # Initialisation des variables pour l'optimiseur Adam APRÈS l'initialisation des poids et biais
        self.m_w = [np.zeros_like(w) for w in self.weights]
        self.v_w = [np.zeros_like(w) for w in self.weights]
        self.m_b = [np.zeros_like(b) for b in self.biases]
        self.v_b = [np.zeros_like(b) for b in self.biases]
        self.t = 0 # time step
        self.beta1 = 0.9
        self.beta2 = 0.999
        self.epsilon = 1e-8 # une variable epsilon pour eviter la division sur 0

    def forward(self , X):
        """
        Forward propagation: Z^{[l]} = A^{[l-1]} W^{[l]} + b^{[l]}, A^{[l]} = g(Z^{[l]})
        """
        assert isinstance(X, np.ndarray), "Input X must be a numpy array"
        assert X.shape [1] == self.layer_sizes [0], f"Input dimension ({X.shape [1]}) must match input layer size ({self.layer_sizes [0]})"
        self.activations = [X]
        self.z_values = []

        for i in range(len(self.weights) - 1):
            z = np.dot(self.activations[-1],self.weights[i])+self.biases[i]
            assert z.shape == (X.shape[0], self.layer_sizes[i+1]),f"Z^{[i+1]} has incorrect shape"
            self.z_values.append(z)
            self.activations.append(relu(z))

        z=np.dot(self.activations[-1],self.weights[-1])+self.biases[-1]

        assert z.shape == (X.shape[0], self.layer_sizes [-1]), "Output Z has incorrect shape"
        self.z_values.append(z)
        
        output = softmax(z)
        assert output.shape == (X.shape[0], self.layer_sizes [-1]),"Output A has incorrect shape"
        self.activations.append(output)

        return self.activations [-1]

    def compute_loss(self , y_true , y_pred):
        """
        Categorical Cross -Entropy: J = -1/m * sum(y_true * log(y_pred))
        """
        assert isinstance(y_true , np.ndarray) and isinstance(y_pred , np.ndarray), "Inputs to loss must be numpy arrays"

        assert y_true.shape == y_pred.shape , "y_true and y_pred must have the same shape"

        y_pred = np.clip(y_pred , 1e-15, 1 - 1e-15)
        m = y_true . shape [0]

        loss = (-1/m)*np.sum(y_true*np.log(y_pred))
        assert not np.isnan(loss), "Loss computation resulted in NaN"
                             
        return loss 

    def compute_accuracy(self , y_true , y_pred):
        """
        Compute accuracy: proportion of correct predictions
        """
        assert isinstance(y_true , np.ndarray) and isinstance(y_pred , np.ndarray), "Inputs to accuracy must be numpy arrays"

        assert y_true.shape == y_pred.shape , "y_true and y_pred must have the same shape"

        predictions = np.argmax(y_pred , axis =1)

        true_labels = np.argmax(y_true , axis =1)
        accuracy = np.mean(predictions == true_labels)
        assert 0 <= accuracy <= 1, "Accuracy must be between 0 and 1"
        return accuracy

    def backward(self , X, y, outputs):
        """
        Backpropagation: compute dW^{[l]}, db^{[l]} for each layer
        """
        assert isinstance(X, np.ndarray) and isinstance(y, np.ndarray) and isinstance(outputs , np.ndarray), "Inputs to backward must be numpy arrays"

        assert X.shape [1] == self.layer_sizes [0], f"Input dimension ({X.shape [1]}) must match input layer size ({self.layer_sizes [0]})"

        assert y.shape == outputs.shape , "y and outputs must have the same shape"

        m = X.shape [0]
        self.d_weights = [ np . zeros_like (w ) for w in self . weights ]
        self.d_biases = [ np . zeros_like ( b) for b in self . biases ]

        dZ = outputs - y # Gradient pour softmax + cross -entropy
       

        
        assert dZ.shape == outputs.shape , "dZ for output layer has incorrect shape"
        self.d_weights [-1] = (self.activations [-2].T @ dZ) / m
        self.d_biases [-1] = np.sum(dZ, axis=0, keepdims=True) / m

        for i in range(len(self.weights) - 2, -1, -1):
            # dZ = np.dot(dZ[i+1],self.weights[i+1].T)*relu_derivative(self.z_values[i])#TODO
            dZ = dZ @ self.weights[i+1].T
            dZ = dZ * relu_derivative(self.z_values[i])
            assert dZ.shape == (X.shape[0], self.layer_sizes[i+1]), f"dZ^{[i+1]} has incorrect shape"
            self.d_weights[i] = (self.activations[i].T @ dZ) / m
            self.d_biases[i] = np.sum(dZ, axis=0, keepdims=True) / m

        # TODO: Ajouter une r gularisation L2 aux gradients des poids

        # dW^{[l]} += lambda * W^{[l]} / m, o lambda est le coefficient de r gularisation
        lamda=0.1
        for i in range(len(self.weights)):
            self.d_weights[i]+=lamda*self.weights[i]/m
        

        if self.model_optimization == "SGD":
            # calcule avec gradient descent stochastic
            for i in range (len ( self . weights )) :
              self. weights [ i] -= self . learning_rate * self . d_weights [ i]
              self . biases [ i] -= self . learning_rate * self . d_biases [ i]
        elif self.model_optimization == "Adam":
            # calcule avec Adam
            self.t += 1 # Increment time step per batch
    
            for i in range (len ( self . weights )) :
                # Mise à jour des moments
                self.m_w[i] = self.beta1 * self.m_w[i] + (1 - self.beta1) * self.d_weights[i]
                self.v_w[i] = self.beta2 * self.v_w[i] + (1 - self.beta2) * (self.d_weights[i]**2)
                self.m_b[i] = self.beta1 * self.m_b[i] + (1 - self.beta1) * self.d_biases[i]
                self.v_b[i] = self.beta2 * self.v_b[i] + (1 - self.beta2) * (self.d_biases[i]**2)
    
                # Correctif de biais
                m_w_hat = self.m_w[i] / (1 - self.beta1**self.t)# mise à jour du 1er moment (momentum)
                v_w_hat = self.v_w[i] / (1 - self.beta2**self.t)# mise à jour du 2e moment (RMS)
                m_b_hat = self.m_b[i] / (1 - self.beta1**self.t)# mise à jour du 1er moment (momentum) (sur le biais)
                v_b_hat = self.v_b[i] / (1 - self.beta2**self.t)# mise à jour du 2e moment (RMS)(sur le biais)
    
                # Update des paramètres
                self . weights [ i] -= self . learning_rate  * m_w_hat / (np.sqrt(v_w_hat) + self.epsilon)
                self . biases [ i] -= self . learning_rate  * m_b_hat / (np.sqrt(v_b_hat) + self.epsilon)






    def train(self , X, y, X_val , y_val , epochs , batch_size):
        """
        Train the neural network using mini -batch SGD , with validation
        """
        assert isinstance(X, np.ndarray) and isinstance(y, np.ndarray), "X and y must be numpy arrays"
        assert isinstance(X_val , np.ndarray) and isinstance(y_val ,np.ndarray), "X_val and y_val must be numpy arrays"

        assert X.shape [1] == self.layer_sizes [0], f"Input dimension ({X.shape [1]}) must match input layer size ({self.layer_sizes [0]})"
        assert y.shape [1] == self.layer_sizes [-1], f"Output dimension ({y.shape [1]}) must match output layer size({self.layer_sizes [-1]})"
        assert X_val.shape [1] == self.layer_sizes [0], f"Validation input dimension ({X_val.shape [1]}) must match input layer size ({self.layer_sizes [0]})"
        assert y_val.shape [1] == self.layer_sizes [-1], f"Validation output dimension ({y_val.shape [1]}) must match output layer size ({self.layer_sizes [-1]})"
        assert isinstance(epochs , int) and epochs > 0, "Epochs must be a positive integer"
        assert isinstance(batch_size , int) and batch_size > 0, "Batch size must be a positive integer"

        train_losses = []
        val_losses = []
        train_accuracies = []
        val_accuracies = []

        for epoch in range(epochs):
            indices = np.random.permutation(X.shape [0])
            X_shuffled = X[indices]
            y_shuffled = y[indices]

            epoch_loss = 0
            for i in range(0, X.shape[0], batch_size):
                X_batch = X_shuffled[i:i+batch_size]
                y_batch = y_shuffled[i:i+batch_size]

                outputs = self.forward(X_batch)
                epoch_loss += self.compute_loss(y_batch , outputs)
                self.backward(X_batch , y_batch , outputs)

            # Calculer les pertes et accuracies
            train_loss = epoch_loss / (X.shape [0] // batch_size)
            train_pred = self.forward(X)
            train_accuracy = self.compute_accuracy(y, train_pred)
            val_pred = self.forward(X_val)
            val_loss = self.compute_loss(y_val , val_pred)
            val_accuracy = self.compute_accuracy(y_val , val_pred)

            train_losses.append(train_loss)
            val_losses.append(val_loss)
            train_accuracies.append(train_accuracy)
            val_accuracies.append(val_accuracy)

            if epoch % 10 == 0:
                print(f"Epoch {epoch}, Train Loss: {train_loss :.4f}, Val Loss: {val_loss :.4f}, "f"Train Acc: {train_accuracy :.4f}, Val Acc:{val_accuracy :.4f}")

        return train_losses , val_losses , train_accuracies ,val_accuracies

    def predict(self , X):
        """
        Predict class labels
        """
        assert isinstance(X, np.ndarray), "Input X must be a numpy array"
        assert X.shape [1] == self.layer_sizes [0], f"Input dimension ({X.shape [1]}) must match input layer size ({self.layer_sizes [0]})"

        outputs = self.forward(X)
        predictions = np.argmax(outputs , axis =1)
        assert predictions.shape == (X.shape[0],), "Predictions have incorrect shape"
        return predictions

# %%
import os
import sys

# 1) À adapter à vos chemins
latin_labels_txt    = 'C:/Users/yyyiyi/Downloads/amhcd/labels/labels/33-common-latin-tifinagh.txt'
tifinagh_labels_txt = 'C:/Users/yyyiyi/Downloads/amhcd/labels/labels/sorted-33-common-tifinagh.txt'
images_root         = 'C:/Users/yyyiyi/Downloads/amhcd/AMHCD_64/AMHCD_64'
output_csv          = 'C:/Users/yyyiyi/Downloads/amhcd/AMHCD_64/AMHCD_64/new-labels-map.csv'

# 2) Lire les labels Latin et les glyphes Tifinagh
with open(latin_labels_txt, 'r', encoding='utf-8') as f:
    ascii_labels = [line.strip() for line in f if line.strip()]

with open(tifinagh_labels_txt, 'r', encoding='utf-8') as f:
    tif_chars = [line.strip() for line in f if line.strip()]

# 3) Vérification  
if len(ascii_labels) != len(tif_chars):
    print(f"❌ Erreur : {len(ascii_labels)} labels Latin ≠ {len(tif_chars)} glyphes Tifinagh")
    sys.exit(1)

# 4) Génération du CSV
with open(output_csv, 'w', encoding='utf-8', newline='') as out:
    for latin, tif in zip(ascii_labels, tif_chars):
        folder = os.path.join(images_root, latin)
        if not os.path.isdir(folder):
            print(f"⚠️ Dossier introuvable, je passe : {folder}")
            continue
        for fname in sorted(os.listdir(folder)):
            # filtrer si nécessaire par extension d’image
            if not fname.lower().endswith(('.png','.jpg','.jpeg','.bmp','.tif','.tiff')):
                continue
            rel_path = f"./AMHCD_64/AMHCD_64/AMHCD_64/{latin}/{fname}"
            # Écrire UNE ligne contenant chemin + glyphe
            out.write(f"{rel_path},{tif}\n")

print(f"✅ Généré {output_csv} avec {sum(len(os.listdir(os.path.join(images_root,l))) for l in ascii_labels if os.path.isdir(os.path.join(images_root,l)))} entrées.")
# Out:
# ✅ Généré /Users/hicham/Downloads/new-labels-map.csv avec 25740 entrées.

# %%
import os
import pandas as pd
import numpy as np
import cv2
from pathlib import Path
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# 1) dossier racine
data_dir = 'C:/Users/yyyiyi/Downloads/amhcd/AMHCD_64/AMHCD_64'
csv_path = os.path.join(data_dir, 'new-labels-map.csv')

# 2) lire le CSV (rel_path + glyphe UTF-8)
df = pd.read_csv(
    csv_path,
    header=None,
    names=['rel_path', 'glyph'],
    dtype=str,
    encoding='utf-8'
)

# 3) NORMALISATION des chemins : ne garder que label/filename
def make_full_path(rel_p):
    p = Path(rel_p.lstrip('./'))           # supprime un "./" initial
    sub = p.parts[-2:]                     # ne garder que les 2 derniers segments
    return os.path.join(data_dir, *sub)

df['image_path'] = df['rel_path'].apply(make_full_path)

# 4) vérification d’existence
missing = df.loc[~df['image_path'].apply(os.path.exists), 'image_path']
if not missing.empty:
    raise FileNotFoundError("Fichiers introuvables :\n" + "\n".join(missing.tolist()))
print(f"✅ Chargé {len(df)} images, {df['glyph'].nunique()} classes.")

# 5) encoder les glyphes en entiers
le = LabelEncoder()
df['label_enc'] = le.fit_transform(df['glyph'])
num_classes = len(le.classes_)

# 6) fonction de chargement et prétraitement
def load_and_preprocess(path, target_size=(32,32)):
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise IOError(f"Impossible de charger : {path}")
    img = cv2.resize(img, target_size)
    return (img.astype(np.float32) / 255.0).flatten()

# 7) construire X et y
X = np.stack([load_and_preprocess(p) for p in df['image_path']])
y = df['label_enc'].values

# 8) split train/val/test
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.20, stratify=y, random_state=42
)
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.25, stratify=y_temp, random_state=42
)
print(f"Train={len(X_train)}, Val={len(X_val)}, Test={len(X_test)}")

# 9) one-hot encoding pour l’entraînement
ohe = OneHotEncoder(sparse_output=False)
y_train_1h = ohe.fit_transform(y_train.reshape(-1,1))
y_val_1h   = ohe.transform(y_val.reshape(-1,1))




# 10) entraîner le modèle
layers = [X_train.shape[1], 64, 32, num_classes]
nn = MultiClassNeuralNetwork(layers, model_optimization="Adam", learning_rate=0.001)
train_losses, val_losses, train_acc, val_acc = nn.train(
    X_train, y_train_1h,
    X_val,   y_val_1h,
    epochs=100, batch_size=64
)

# 11) évaluer sur test
y_pred = nn.predict(X_test)
print("\n=== Classification Report (Test) ===")
print(classification_report(y_test, y_pred, target_names=le.classes_))

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Matrice de confusion (Test)')
plt.xlabel('Prédit')
plt.ylabel('Réel')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()



# Courbes de perte et d’accuracy
fig , (ax1 , ax2) = plt.subplots(1, 2, figsize =(12, 5))

# Courbe de perte
ax1.plot(train_losses , label='Train Loss')
ax1.plot(val_losses , label='Validation Loss')
ax1.set_title('Courbe de perte')
ax1.set_xlabel(' poque ')
ax1.set_ylabel('Perte')
ax1.legend ()

# Courbe d’accuracy
ax2.plot(train_acc , label='Train Accuracy ')
ax2.plot(val_acc , label='Validation Accuracy ')
ax2.set_title('Courbe de p r c i s i o n ')
ax2.set_xlabel(' poque ')
ax2.set_ylabel(' P r c i s i o n ')
ax2.legend ()

plt.tight_layout ()
fig.savefig('loss_accuracy_plot.png')
plt.show()
# Out:
# ✅ Chargé 25740 images, 33 classes.
# Train=15444, Val=5148, Test=5148
# Epoch 0, Train Loss: 3.5113, Val Loss: 3.4965, Train Acc: 0.0303, Val Acc:0.0303
# Epoch 10, Train Loss: 2.7198, Val Loss: 2.6771, Train Acc: 0.1204, Val Acc:0.1189
# Epoch 20, Train Loss: 2.4338, Val Loss: 2.3593, Train Acc: 0.2558, Val Acc:0.2514
# Epoch 30, Train Loss: 1.9566, Val Loss: 1.9200, Train Acc: 0.3633, Val Acc:0.3648
# Epoch 40, Train Loss: 1.6343, Val Loss: 1.5893, Train Acc: 0.4902, Val Acc:0.4810
# Epoch 50, Train Loss: 1.3536, Val Loss: 1.3107, Train Acc: 0.5853, Val Acc:0.5831
# Epoch 60, Train Loss: 1.2276, Val Loss: 1.2538, Train Acc: 0.6086, Val Acc:0.6018
# Epoch 70, Train Loss: 1.0499, Val Loss: 1.0697, Train Acc: 0.6692, Val Acc:0.6577
# Epoch 80, Train Loss: 0.8939, Val Loss: 1.0392, Train Acc: 0.6737, Val Acc:0.6647
# Epoch 90, Train Loss: 0.7958, Val Loss: 0.8088, Train Acc: 0.7747, Val Acc:0.7622
#
# === Classification Report (Test) ===
#               precision    recall  f1-score   support
#
#            ⴰ       0.93      0.98      0.95       156
#            ⴱ       0.91      0.92      0.91       156
#            ⴳ       0.82      0.72      0.77       156
#           ⴳⵯ       0.62      0.89      0.73       156
#            ⴷ       0.68      0.86      0.76       156
#            ⴹ       0.57      0.67      0.62       156
#            ⴻ       0.71      0.88      0.79       156
#            ⴼ       0.69      0.87      0.77       156
#            ⴽ       0.81      0.78      0.79       156
#           ⴽⵯ       0.86      0.62      0.72       156
#            ⵀ       0.83      0.66      0.74       156
#            ⵃ       0.62      0.77      0.69       156
#            ⵄ       0.92      0.72      0.81       156
#            ⵅ       0.65      0.71      0.68       156
#            ⵇ       0.87      0.58      0.70       156
#            ⵉ       0.67      0.83      0.74       156
#            ⵊ       0.90      0.84      0.87       156
#            ⵍ       0.90      0.76      0.83       156
#            ⵎ       0.63      0.86      0.73       156
#            ⵏ       0.81      0.90      0.85       156
#            ⵓ       0.72      0.85      0.78       156
#            ⵔ       0.69      0.88      0.77       156
#            ⵕ       0.69      0.68      0.69       156
#            ⵖ       0.93      0.70      0.80       156
#            ⵙ       0.72      0.59      0.65       156
#            ⵚ       0.90      0.65      0.76       156
#            ⵛ       0.77      0.75      0.76       156
#            ⵜ       0.90      0.79      0.84       156
#            ⵟ       0.79      0.63      0.70       156
#            ⵡ       0.91      0.93      0.92       156
#            ⵢ       0.58      0.72      0.64       156
#            ⵣ       0.70      0.32      0.44       156
#            ⵥ       0.69      0.52      0.59       156
#
#     accuracy                           0.75      5148
#    macro avg       0.77      0.75      0.75      5148
# weighted avg       0.77      0.75      0.75      5148

# %%
# ----- Définir les hyperparamètres à tester -----
learning_rates = [0.001, 0.01, 0.1]
batch_sizes    = [128, 256, 512]
n_splits       = 5

# Préparer un tableau pour stocker la performance moyenne (accuracy) pour chaque combinaison
mean_val_accuracy = np.zeros((len(learning_rates), len(batch_sizes)))

# ----- Créer une version one-hot de y_temp pour la CV -----
one_hot_encoder = OneHotEncoder(sparse_output=False)
y_temp_one_hot = one_hot_encoder.fit_transform(y_temp.reshape(-1, 1))
assert y_temp_one_hot.shape[0] == X_temp.shape[0] and y_temp_one_hot.shape[1] == num_classes
# Boucle de recherche par cross-validation sur chaque combinaison de hyperparamètres


for i, lr in enumerate(learning_rates):
    for j, bs in enumerate(batch_sizes):
        print(f"Testing learning_rate={lr}, batch_size={bs} ...")
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
        fold_accuracies = []

        for train_index, val_index in kf.split(X_temp):
            X_train_fold = X_temp[train_index]
            X_val_fold   = X_temp[val_index]
            y_train_fold = y_temp_one_hot[train_index]
            y_val_fold   = y_temp_one_hot[val_index]

            # Initialiser un nouveau modèle avec le learning rate courant
            layer_sizes = [X_train_fold.shape[1], 64, 32, num_classes]
            nn = MultiClassNeuralNetwork(layer_sizes, model_optimization="Adam",learning_rate=lr)

            # Entraîner sur ce fold
            _, val_losses, _, val_accs = nn.train(
                X_train_fold, y_train_fold,
                X_val_fold,   y_val_fold,
                epochs=100, batch_size=bs
            )

            # Récupérer la dernière accuracy du fold de validation
            fold_accuracies.append(val_accs[-1])

        # Calculer la moyenne des accuracies sur les n_splits folds
        mean_val_accuracy[i, j] = np.mean(fold_accuracies)
        print(f"→ Moyenne CV accuracy pour lr={lr}, bs={bs} : {mean_val_accuracy[i, j]:.4f}")

# Déterminer la combinaison qui a la performance la plus élevée
best_idx = np.unravel_index(np.argmax(mean_val_accuracy), mean_val_accuracy.shape)
best_lr  = learning_rates[best_idx[0]]
best_bs  = batch_sizes[best_idx[1]]
best_acc = mean_val_accuracy[best_idx]
print(f"\nMeilleure combinaison : learning_rate={best_lr}, batch_size={best_bs} avec CV accuracy={best_acc:.4f}")

# ----- Visualisation des résultats sous forme de heatmap -----
plt.figure(figsize=(8, 6))
sns.heatmap(
    mean_val_accuracy,
    annot=True, fmt=".4f",
    xticklabels=batch_sizes,
    yticklabels=learning_rates,
    cmap="YlGnBu"
)
plt.title("Moyenne CV Accuracy\npour chaque combinaison de learning_rate et batch_size")
plt.xlabel("Batch size")
plt.ylabel("Learning rate")
plt.savefig("cv_accuracy_heatmap.png")
plt.show()

# ----- Réentraîner un modèle final sur tout X_temp avec la meilleure combinaison -----
layer_sizes_final = [X_temp.shape[1], 64, 32, num_classes]
nn_final = MultiClassNeuralNetwork(layer_sizes_final,  model_optimization="Adam",learning_rate=best_lr)
# Reconstruire y_temp_one_hot si nécessaire :
# y_temp_one_hot = one_hot_encoder.fit_transform(y_temp.reshape(-1, 1))
nn_final.train(X_temp, y_temp_one_hot, X_temp, y_temp_one_hot, epochs=100, batch_size=best_bs)

# ----- Évaluer le modèle final sur le jeu de test -----
y_test_pred = nn_final.predict(X_test)
print("\nRapport de classification (Test set) avec la meilleure combinaison :")
print(classification_report(y_test, y_test_pred, target_names=label_encoder.classes_))

# Matrice de confusion (Test set)
cm = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title(f"Matrice de confusion (Test set) - lr={best_lr}, bs={best_bs}")
plt.xlabel("Prédit")
plt.ylabel("Réel")
plt.savefig("confusion_matrix_best.png")
plt.show()
# Out:
# Testing learning_rate=0.001, batch_size=128 ...
# Epoch 0, Train Loss: 3.4930, Val Loss: 3.2454, Train Acc: 0.0567, Val Acc:0.0619
# Epoch 10, Train Loss: 2.7214, Val Loss: 2.6946, Train Acc: 0.1109, Val Acc:0.1037
# Epoch 20, Train Loss: 2.2348, Val Loss: 2.2012, Train Acc: 0.2764, Val Acc:0.2824
# Epoch 30, Train Loss: 1.8074, Val Loss: 1.7464, Train Acc: 0.4362, Val Acc:0.4428
# Epoch 40, Train Loss: 1.2435, Val Loss: 1.2428, Train Acc: 0.6267, Val Acc:0.6312
# Epoch 50, Train Loss: 0.8372, Val Loss: 0.8098, Train Acc: 0.7772, Val Acc:0.7822
# Epoch 60, Train Loss: 0.7019, Val Loss: 0.7325, Train Acc: 0.8024, Val Acc:0.7883
# Epoch 70, Train Loss: 0.6040, Val Loss: 0.6037, Train Acc: 0.8430, Val Acc:0.8318
# Epoch 80, Train Loss: 0.5192, Val Loss: 0.5848, Train Acc: 0.8529, Val Acc:0.8407
# Epoch 90, Train Loss: 0.4974, Val Loss: 0.5362, Train Acc: 0.8703, Val Acc:0.8517
# Epoch 0, Train Loss: 3.4731, Val Loss: 3.1756, Train Acc: 0.0761, Val Acc:0.0702
# Epoch 10, Train Loss: 2.5999, Val Loss: 2.5578, Train Acc: 0.1946, Val Acc:0.1976
# Epoch 20, Train Loss: 1.9567, Val Loss: 1.9705, Train Acc: 0.3352, Val Acc:0.3253
# Epoch 30, Train Loss: 1.6350, Val Loss: 1.6087, Train Acc: 0.4944, Val Acc:0.4797
# Epoch 40, Train Loss: 1.0671, Val Loss: 1.1858, Train Acc: 0.6562, Val Acc:0.6341
# Epoch 50, Train Loss: 0.8817, Val Loss: 0.9059, Train Acc: 0.7420, Val Acc:0.7181
# Epoch 60, Train Loss: 0.7465, Val Loss: 0.9305, Train Acc: 0.7378, Val Acc:0.7041
# Epoch 70, Train Loss: 0.6466, Val Loss: 0.7820, Train Acc: 0.7905, Val Acc:0.7626
# Epoch 80, Train Loss: 0.5748, Val Loss: 0.6773, Train Acc: 0.8233, Val Acc:0.7817
# Epoch 90, Train Loss: 0.5174, Val Loss: 0.5581, Train Acc: 0.8726, Val Acc:0.8403
# Epoch 0, Train Loss: 3.5241, Val Loss: 3.4967, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 10, Train Loss: 2.5544, Val Loss: 2.4405, Train Acc: 0.2259, Val Acc:0.2200
# Epoch 20, Train Loss: 2.0104, Val Loss: 2.0079, Train Acc: 0.2996, Val Acc:0.2987
# Epoch 30, Train Loss: 1.9588, Val Loss: 1.9944, Train Acc: 0.3115, Val Acc:0.3181
# Epoch 40, Train Loss: 1.9398, Val Loss: 1.8902, Train Acc: 0.3652, Val Acc:0.3609
# Epoch 50, Train Loss: 1.4648, Val Loss: 1.4658, Train Acc: 0.5412, Val Acc:0.5464
# Epoch 60, Train Loss: 1.3068, Val Loss: 1.3256, Train Acc: 0.5897, Val Acc:0.5864
# Epoch 70, Train Loss: 1.1887, Val Loss: 1.1736, Train Acc: 0.6561, Val Acc:0.6421
# Epoch 80, Train Loss: 1.0707, Val Loss: 1.0854, Train Acc: 0.6791, Val Acc:0.6608
# Epoch 90, Train Loss: 0.9878, Val Loss: 1.0685, Train Acc: 0.6867, Val Acc:0.6680
# Epoch 0, Train Loss: 3.5229, Val Loss: 3.4869, Train Acc: 0.0306, Val Acc:0.0301
# Epoch 10, Train Loss: 2.6992, Val Loss: 2.7168, Train Acc: 0.1397, Val Acc:0.1287
# Epoch 20, Train Loss: 1.6077, Val Loss: 1.5478, Train Acc: 0.5003, Val Acc:0.5083
# Epoch 30, Train Loss: 1.3801, Val Loss: 1.3719, Train Acc: 0.5443, Val Acc:0.5437
# Epoch 40, Train Loss: 1.3110, Val Loss: 1.3255, Train Acc: 0.5710, Val Acc:0.5673
# Epoch 50, Train Loss: 1.1820, Val Loss: 1.2145, Train Acc: 0.6227, Val Acc:0.6158
# Epoch 60, Train Loss: 0.9836, Val Loss: 1.0005, Train Acc: 0.7134, Val Acc:0.6833
# Epoch 70, Train Loss: 0.8496, Val Loss: 0.9058, Train Acc: 0.7405, Val Acc:0.7176
# Epoch 80, Train Loss: 0.7201, Val Loss: 0.7692, Train Acc: 0.7905, Val Acc:0.7773
# Epoch 90, Train Loss: 0.6377, Val Loss: 0.6936, Train Acc: 0.8172, Val Acc:0.7999
# Epoch 0, Train Loss: 3.5207, Val Loss: 3.4616, Train Acc: 0.0316, Val Acc:0.0316
# Epoch 10, Train Loss: 2.7066, Val Loss: 2.7031, Train Acc: 0.1135, Val Acc:0.1083
# Epoch 20, Train Loss: 2.1058, Val Loss: 2.1400, Train Acc: 0.3221, Val Acc:0.3094
# Epoch 30, Train Loss: 1.5109, Val Loss: 1.4718, Train Acc: 0.5402, Val Acc:0.5316
# Epoch 40, Train Loss: 1.3478, Val Loss: 1.3455, Train Acc: 0.5889, Val Acc:0.5794
# Epoch 50, Train Loss: 1.2791, Val Loss: 1.2827, Train Acc: 0.6087, Val Acc:0.5996
# Epoch 60, Train Loss: 1.1668, Val Loss: 1.1995, Train Acc: 0.6498, Val Acc:0.6287
# Epoch 70, Train Loss: 0.9730, Val Loss: 1.0140, Train Acc: 0.7096, Val Acc:0.6926
# Epoch 80, Train Loss: 0.8475, Val Loss: 0.8817, Train Acc: 0.7593, Val Acc:0.7407
# Epoch 90, Train Loss: 0.7406, Val Loss: 0.7597, Train Acc: 0.8064, Val Acc:0.7924
# → Moyenne CV accuracy pour lr=0.001, bs=128 : 0.8010
# Testing learning_rate=0.001, batch_size=256 ...
# Epoch 0, Train Loss: 3.5512, Val Loss: 3.4964, Train Acc: 0.0318, Val Acc:0.0243
# Epoch 10, Train Loss: 2.7614, Val Loss: 2.7064, Train Acc: 0.1157, Val Acc:0.1027
# Epoch 20, Train Loss: 2.7109, Val Loss: 2.6902, Train Acc: 0.1135, Val Acc:0.1015
# Epoch 30, Train Loss: 2.0628, Val Loss: 1.9972, Train Acc: 0.3274, Val Acc:0.3275
# Epoch 40, Train Loss: 1.9713, Val Loss: 1.8980, Train Acc: 0.3636, Val Acc:0.3547
# Epoch 50, Train Loss: 1.6700, Val Loss: 1.6193, Train Acc: 0.4988, Val Acc:0.5035
# Epoch 60, Train Loss: 1.4468, Val Loss: 1.4457, Train Acc: 0.5575, Val Acc:0.5550
# Epoch 70, Train Loss: 1.3835, Val Loss: 1.3764, Train Acc: 0.5769, Val Acc:0.5766
# Epoch 80, Train Loss: 1.3179, Val Loss: 1.3207, Train Acc: 0.6037, Val Acc:0.6065
# Epoch 90, Train Loss: 1.2666, Val Loss: 1.2768, Train Acc: 0.6193, Val Acc:0.6227
# Epoch 0, Train Loss: 3.5464, Val Loss: 3.4579, Train Acc: 0.0626, Val Acc:0.0556
# Epoch 10, Train Loss: 2.0521, Val Loss: 2.0592, Train Acc: 0.3115, Val Acc:0.3086
# Epoch 20, Train Loss: 1.9657, Val Loss: 1.9523, Train Acc: 0.3457, Val Acc:0.3331
# Epoch 30, Train Loss: 1.9142, Val Loss: 1.9466, Train Acc: 0.3582, Val Acc:0.3462
# Epoch 40, Train Loss: 1.8550, Val Loss: 1.8580, Train Acc: 0.3856, Val Acc:0.3797
# Epoch 50, Train Loss: 1.5458, Val Loss: 1.5472, Train Acc: 0.5306, Val Acc:0.5147
# Epoch 60, Train Loss: 1.0965, Val Loss: 1.0992, Train Acc: 0.6763, Val Acc:0.6550
# Epoch 70, Train Loss: 0.8899, Val Loss: 0.9000, Train Acc: 0.7502, Val Acc:0.7240
# Epoch 80, Train Loss: 0.7565, Val Loss: 0.9522, Train Acc: 0.7186, Val Acc:0.7021
# Epoch 90, Train Loss: 0.6409, Val Loss: 0.7739, Train Acc: 0.7938, Val Acc:0.7725
# Epoch 0, Train Loss: 3.5496, Val Loss: 3.4778, Train Acc: 0.0553, Val Acc:0.0510
# Epoch 10, Train Loss: 2.7148, Val Loss: 2.6972, Train Acc: 0.1775, Val Acc:0.1710
# Epoch 20, Train Loss: 2.0391, Val Loss: 2.0148, Train Acc: 0.3317, Val Acc:0.3159
# Epoch 30, Train Loss: 1.9182, Val Loss: 1.9178, Train Acc: 0.3883, Val Acc:0.3798
# Epoch 40, Train Loss: 1.5016, Val Loss: 1.4735, Train Acc: 0.5391, Val Acc:0.5321
# Epoch 50, Train Loss: 1.3575, Val Loss: 1.3184, Train Acc: 0.5753, Val Acc:0.5784
# Epoch 60, Train Loss: 1.2761, Val Loss: 1.2851, Train Acc: 0.5810, Val Acc:0.5746
# Epoch 70, Train Loss: 1.1972, Val Loss: 1.1882, Train Acc: 0.6267, Val Acc:0.6309
# Epoch 80, Train Loss: 1.0357, Val Loss: 1.0388, Train Acc: 0.6775, Val Acc:0.6729
# Epoch 90, Train Loss: 0.8950, Val Loss: 0.8743, Train Acc: 0.7468, Val Acc:0.7421
# Epoch 0, Train Loss: 3.5505, Val Loss: 3.4912, Train Acc: 0.0599, Val Acc:0.0537
# Epoch 10, Train Loss: 2.2951, Val Loss: 2.2124, Train Acc: 0.2793, Val Acc:0.2771
# Epoch 20, Train Loss: 2.0082, Val Loss: 2.0136, Train Acc: 0.3413, Val Acc:0.3465
# Epoch 30, Train Loss: 1.6686, Val Loss: 1.5921, Train Acc: 0.5066, Val Acc:0.5138
# Epoch 40, Train Loss: 1.3151, Val Loss: 1.3049, Train Acc: 0.5952, Val Acc:0.5932
# Epoch 50, Train Loss: 1.0274, Val Loss: 1.0999, Train Acc: 0.6748, Val Acc:0.6707
# Epoch 60, Train Loss: 0.9072, Val Loss: 0.9268, Train Acc: 0.7370, Val Acc:0.7285
# Epoch 70, Train Loss: 0.8488, Val Loss: 0.9048, Train Acc: 0.7392, Val Acc:0.7295
# Epoch 80, Train Loss: 0.7778, Val Loss: 0.8477, Train Acc: 0.7750, Val Acc:0.7589
# Epoch 90, Train Loss: 0.7480, Val Loss: 0.8156, Train Acc: 0.7806, Val Acc:0.7661
# Epoch 0, Train Loss: 3.5507, Val Loss: 3.4903, Train Acc: 0.0362, Val Acc:0.0313
# Epoch 10, Train Loss: 2.6642, Val Loss: 2.5946, Train Acc: 0.1932, Val Acc:0.1846
# Epoch 20, Train Loss: 2.1007, Val Loss: 2.0640, Train Acc: 0.3396, Val Acc:0.3203
# Epoch 30, Train Loss: 2.0199, Val Loss: 2.0107, Train Acc: 0.3485, Val Acc:0.3339
# Epoch 40, Train Loss: 1.9130, Val Loss: 1.8790, Train Acc: 0.4210, Val Acc:0.3961
# Epoch 50, Train Loss: 1.4415, Val Loss: 1.4593, Train Acc: 0.5551, Val Acc:0.5364
# Epoch 60, Train Loss: 1.3108, Val Loss: 1.3348, Train Acc: 0.5977, Val Acc:0.5792
# Epoch 70, Train Loss: 1.2150, Val Loss: 1.2338, Train Acc: 0.6394, Val Acc:0.6209
# Epoch 80, Train Loss: 1.0056, Val Loss: 1.0498, Train Acc: 0.7015, Val Acc:0.6821
# Epoch 90, Train Loss: 0.8824, Val Loss: 0.9069, Train Acc: 0.7536, Val Acc:0.7322
# → Moyenne CV accuracy pour lr=0.001, bs=256 : 0.7572
# Testing learning_rate=0.001, batch_size=512 ...
# Epoch 0, Train Loss: 3.6058, Val Loss: 3.4958, Train Acc: 0.0382, Val Acc:0.0316
# Epoch 10, Train Loss: 2.8054, Val Loss: 2.7028, Train Acc: 0.1186, Val Acc:0.1199
# Epoch 20, Train Loss: 2.7172, Val Loss: 2.6086, Train Acc: 0.1792, Val Acc:0.1627
# Epoch 30, Train Loss: 2.1425, Val Loss: 2.0687, Train Acc: 0.3226, Val Acc:0.3227
# Epoch 40, Train Loss: 2.0425, Val Loss: 1.9945, Train Acc: 0.3381, Val Acc:0.3365
# Epoch 50, Train Loss: 1.9947, Val Loss: 1.9669, Train Acc: 0.3400, Val Acc:0.3360
# Epoch 60, Train Loss: 1.8525, Val Loss: 1.8040, Train Acc: 0.4211, Val Acc:0.4042
# Epoch 70, Train Loss: 1.6094, Val Loss: 1.5734, Train Acc: 0.5072, Val Acc:0.4943
# Epoch 80, Train Loss: 1.4678, Val Loss: 1.4773, Train Acc: 0.5255, Val Acc:0.5055
# Epoch 90, Train Loss: 1.3634, Val Loss: 1.3496, Train Acc: 0.5786, Val Acc:0.5669
# Epoch 0, Train Loss: 3.6053, Val Loss: 3.4938, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 10, Train Loss: 2.2257, Val Loss: 2.1346, Train Acc: 0.3092, Val Acc:0.3032
# Epoch 20, Train Loss: 2.0669, Val Loss: 2.0130, Train Acc: 0.3416, Val Acc:0.3428
# Epoch 30, Train Loss: 1.9128, Val Loss: 1.8795, Train Acc: 0.3968, Val Acc:0.3753
# Epoch 40, Train Loss: 1.5583, Val Loss: 1.5621, Train Acc: 0.5048, Val Acc:0.4965
# Epoch 50, Train Loss: 1.3909, Val Loss: 1.3797, Train Acc: 0.5769, Val Acc:0.5662
# Epoch 60, Train Loss: 1.2529, Val Loss: 1.2448, Train Acc: 0.6389, Val Acc:0.6176
# Epoch 70, Train Loss: 1.0593, Val Loss: 1.0651, Train Acc: 0.6974, Val Acc:0.6747
# Epoch 80, Train Loss: 0.9864, Val Loss: 1.0283, Train Acc: 0.7061, Val Acc:0.6803
# Epoch 90, Train Loss: 0.9058, Val Loss: 0.9414, Train Acc: 0.7361, Val Acc:0.7072
# Epoch 0, Train Loss: 3.6056, Val Loss: 3.4947, Train Acc: 0.0591, Val Acc:0.0573
# Epoch 10, Train Loss: 2.2376, Val Loss: 2.1793, Train Acc: 0.2849, Val Acc:0.2785
# Epoch 20, Train Loss: 2.0826, Val Loss: 2.0630, Train Acc: 0.3150, Val Acc:0.3150
# Epoch 30, Train Loss: 2.0507, Val Loss: 1.9579, Train Acc: 0.3592, Val Acc:0.3565
# Epoch 40, Train Loss: 1.8354, Val Loss: 1.7489, Train Acc: 0.4540, Val Acc:0.4570
# Epoch 50, Train Loss: 1.4451, Val Loss: 1.3873, Train Acc: 0.5580, Val Acc:0.5629
# Epoch 60, Train Loss: 1.3162, Val Loss: 1.2630, Train Acc: 0.6018, Val Acc:0.6000
# Epoch 70, Train Loss: 1.1428, Val Loss: 1.1106, Train Acc: 0.6699, Val Acc:0.6712
# Epoch 80, Train Loss: 1.0193, Val Loss: 1.0025, Train Acc: 0.7094, Val Acc:0.6982
# Epoch 90, Train Loss: 0.9902, Val Loss: 0.9958, Train Acc: 0.7100, Val Acc:0.6972
# Epoch 0, Train Loss: 3.6055, Val Loss: 3.4943, Train Acc: 0.0305, Val Acc:0.0296
# Epoch 10, Train Loss: 2.7770, Val Loss: 2.6652, Train Acc: 0.1621, Val Acc:0.1642
# Epoch 20, Train Loss: 2.1783, Val Loss: 2.1194, Train Acc: 0.3099, Val Acc:0.3118
# Epoch 30, Train Loss: 2.0722, Val Loss: 2.0037, Train Acc: 0.3334, Val Acc:0.3332
# Epoch 40, Train Loss: 1.9812, Val Loss: 1.9355, Train Acc: 0.3752, Val Acc:0.3803
# Epoch 50, Train Loss: 1.5862, Val Loss: 1.5246, Train Acc: 0.5415, Val Acc:0.5342
# Epoch 60, Train Loss: 1.2716, Val Loss: 1.2469, Train Acc: 0.6331, Val Acc:0.6272
# Epoch 70, Train Loss: 1.0457, Val Loss: 1.0453, Train Acc: 0.6954, Val Acc:0.6894
# Epoch 80, Train Loss: 0.9421, Val Loss: 1.0051, Train Acc: 0.7127, Val Acc:0.6960
# Epoch 90, Train Loss: 0.8925, Val Loss: 0.9037, Train Acc: 0.7444, Val Acc:0.7263
# Epoch 0, Train Loss: 3.6058, Val Loss: 3.4956, Train Acc: 0.0618, Val Acc:0.0561
# Epoch 10, Train Loss: 2.3066, Val Loss: 2.3162, Train Acc: 0.2509, Val Acc:0.2530
# Epoch 20, Train Loss: 2.0578, Val Loss: 2.0773, Train Acc: 0.3201, Val Acc:0.2982
# Epoch 30, Train Loss: 2.0019, Val Loss: 1.9566, Train Acc: 0.3500, Val Acc:0.3400
# Epoch 40, Train Loss: 1.9057, Val Loss: 1.8521, Train Acc: 0.4107, Val Acc:0.3941
# Epoch 50, Train Loss: 1.4655, Val Loss: 1.4285, Train Acc: 0.5580, Val Acc:0.5318
# Epoch 60, Train Loss: 1.1405, Val Loss: 1.1302, Train Acc: 0.6703, Val Acc:0.6610
# Epoch 70, Train Loss: 0.9845, Val Loss: 0.9966, Train Acc: 0.7196, Val Acc:0.7037
# Epoch 80, Train Loss: 0.8896, Val Loss: 0.9445, Train Acc: 0.7322, Val Acc:0.7169
# Epoch 90, Train Loss: 0.8387, Val Loss: 0.8558, Train Acc: 0.7699, Val Acc:0.7557
# → Moyenne CV accuracy pour lr=0.001, bs=512 : 0.7063
# Testing learning_rate=0.01, batch_size=128 ...
# Epoch 0, Train Loss: 3.5263, Val Loss: 3.4982, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 10, Train Loss: 3.5253, Val Loss: 3.4983, Train Acc: 0.0310, Val Acc:0.0274
# Epoch 20, Train Loss: 3.5255, Val Loss: 3.4990, Train Acc: 0.0318, Val Acc:0.0243
# Epoch 30, Train Loss: 3.5253, Val Loss: 3.4985, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 40, Train Loss: 3.5253, Val Loss: 3.4990, Train Acc: 0.0318, Val Acc:0.0243
# Epoch 50, Train Loss: 3.5253, Val Loss: 3.4983, Train Acc: 0.0318, Val Acc:0.0243
# Epoch 60, Train Loss: 3.5253, Val Loss: 3.4982, Train Acc: 0.0304, Val Acc:0.0301
# Epoch 70, Train Loss: 3.5256, Val Loss: 3.4988, Train Acc: 0.0311, Val Acc:0.0269
# Epoch 80, Train Loss: 3.5255, Val Loss: 3.4989, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 90, Train Loss: 3.5254, Val Loss: 3.4987, Train Acc: 0.0312, Val Acc:0.0267
# Epoch 0, Train Loss: 3.5261, Val Loss: 3.4985, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 10, Train Loss: 3.5255, Val Loss: 3.4981, Train Acc: 0.0310, Val Acc:0.0274
# Epoch 20, Train Loss: 3.5254, Val Loss: 3.4985, Train Acc: 0.0310, Val Acc:0.0274
# Epoch 30, Train Loss: 3.5254, Val Loss: 3.4986, Train Acc: 0.0310, Val Acc:0.0274
# Epoch 40, Train Loss: 3.5252, Val Loss: 3.4975, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 50, Train Loss: 3.5255, Val Loss: 3.4983, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 60, Train Loss: 3.5253, Val Loss: 3.4993, Train Acc: 0.0310, Val Acc:0.0274
# Epoch 70, Train Loss: 3.5253, Val Loss: 3.4988, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 80, Train Loss: 3.5252, Val Loss: 3.4995, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 90, Train Loss: 3.5253, Val Loss: 3.4989, Train Acc: 0.0307, Val Acc:0.0286
# Epoch 0, Train Loss: 3.5276, Val Loss: 3.4978, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 10, Train Loss: 3.5254, Val Loss: 3.4985, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 20, Train Loss: 3.5256, Val Loss: 3.4968, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 30, Train Loss: 3.5255, Val Loss: 3.4982, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 40, Train Loss: 3.5253, Val Loss: 3.4983, Train Acc: 0.0305, Val Acc:0.0294
# Epoch 50, Train Loss: 3.5256, Val Loss: 3.4981, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 60, Train Loss: 3.5255, Val Loss: 3.4981, Train Acc: 0.0306, Val Acc:0.0291
# Epoch 70, Train Loss: 3.5257, Val Loss: 3.4981, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 80, Train Loss: 3.5257, Val Loss: 3.4979, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 90, Train Loss: 3.5253, Val Loss: 3.4985, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 0, Train Loss: 3.5273, Val Loss: 3.4983, Train Acc: 0.0315, Val Acc:0.0255
# Epoch 10, Train Loss: 3.5255, Val Loss: 3.4981, Train Acc: 0.0315, Val Acc:0.0255
# Epoch 20, Train Loss: 3.5255, Val Loss: 3.4980, Train Acc: 0.0304, Val Acc:0.0301
# Epoch 30, Train Loss: 3.5255, Val Loss: 3.4980, Train Acc: 0.0315, Val Acc:0.0255
# Epoch 40, Train Loss: 3.5255, Val Loss: 3.4993, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 50, Train Loss: 3.5253, Val Loss: 3.4987, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 60, Train Loss: 3.5253, Val Loss: 3.4992, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 70, Train Loss: 3.5254, Val Loss: 3.4987, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 80, Train Loss: 3.5255, Val Loss: 3.4980, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 90, Train Loss: 3.5256, Val Loss: 3.4981, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 0, Train Loss: 3.5263, Val Loss: 3.4986, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 10, Train Loss: 3.5255, Val Loss: 3.4975, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 20, Train Loss: 3.5253, Val Loss: 3.4975, Train Acc: 0.0304, Val Acc:0.0301
# Epoch 30, Train Loss: 3.5254, Val Loss: 3.4980, Train Acc: 0.0312, Val Acc:0.0267
# Epoch 40, Train Loss: 3.5254, Val Loss: 3.4979, Train Acc: 0.0307, Val Acc:0.0289
# Epoch 50, Train Loss: 3.5255, Val Loss: 3.4979, Train Acc: 0.0310, Val Acc:0.0277
# Epoch 60, Train Loss: 3.5254, Val Loss: 3.4980, Train Acc: 0.0307, Val Acc:0.0289
# Epoch 70, Train Loss: 3.5256, Val Loss: 3.4984, Train Acc: 0.0306, Val Acc:0.0291
# Epoch 80, Train Loss: 3.5256, Val Loss: 3.4978, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 90, Train Loss: 3.5252, Val Loss: 3.4980, Train Acc: 0.0305, Val Acc:0.0294
# → Moyenne CV accuracy pour lr=0.01, bs=128 : 0.0268
# Testing learning_rate=0.01, batch_size=256 ...
# Epoch 0, Train Loss: 3.5532, Val Loss: 3.4981, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 10, Train Loss: 3.5521, Val Loss: 3.4982, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 20, Train Loss: 3.5522, Val Loss: 3.4984, Train Acc: 0.0318, Val Acc:0.0243
# Epoch 30, Train Loss: 3.5521, Val Loss: 3.4983, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 40, Train Loss: 3.5521, Val Loss: 3.4985, Train Acc: 0.0318, Val Acc:0.0243
# Epoch 50, Train Loss: 3.5521, Val Loss: 3.4979, Train Acc: 0.0318, Val Acc:0.0243
# Epoch 60, Train Loss: 3.5521, Val Loss: 3.4981, Train Acc: 0.0312, Val Acc:0.0267
# Epoch 70, Train Loss: 3.5524, Val Loss: 3.4985, Train Acc: 0.0311, Val Acc:0.0269
# Epoch 80, Train Loss: 3.5523, Val Loss: 3.4986, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 90, Train Loss: 3.5521, Val Loss: 3.4985, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 0, Train Loss: 3.5529, Val Loss: 3.4982, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 10, Train Loss: 3.5523, Val Loss: 3.4982, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 20, Train Loss: 3.5521, Val Loss: 3.4985, Train Acc: 0.0310, Val Acc:0.0274
# Epoch 30, Train Loss: 3.5522, Val Loss: 3.4983, Train Acc: 0.0310, Val Acc:0.0274
# Epoch 40, Train Loss: 3.5521, Val Loss: 3.4981, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 50, Train Loss: 3.5522, Val Loss: 3.4984, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 60, Train Loss: 3.5521, Val Loss: 3.4985, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 70, Train Loss: 3.5521, Val Loss: 3.4986, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 80, Train Loss: 3.5521, Val Loss: 3.4988, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 90, Train Loss: 3.5521, Val Loss: 3.4984, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 0, Train Loss: 3.5535, Val Loss: 3.4977, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 10, Train Loss: 3.5523, Val Loss: 3.4980, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 20, Train Loss: 3.5524, Val Loss: 3.4974, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 30, Train Loss: 3.5522, Val Loss: 3.4977, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 40, Train Loss: 3.5522, Val Loss: 3.4977, Train Acc: 0.0305, Val Acc:0.0296
# Epoch 50, Train Loss: 3.5525, Val Loss: 3.4977, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 60, Train Loss: 3.5523, Val Loss: 3.4978, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 70, Train Loss: 3.5524, Val Loss: 3.4979, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 80, Train Loss: 3.5523, Val Loss: 3.4977, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 90, Train Loss: 3.5521, Val Loss: 3.4979, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 0, Train Loss: 3.5529, Val Loss: 3.4981, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 10, Train Loss: 3.5522, Val Loss: 3.4981, Train Acc: 0.0315, Val Acc:0.0255
# Epoch 20, Train Loss: 3.5522, Val Loss: 3.4979, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 30, Train Loss: 3.5523, Val Loss: 3.4984, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 40, Train Loss: 3.5522, Val Loss: 3.4984, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 50, Train Loss: 3.5521, Val Loss: 3.4982, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 60, Train Loss: 3.5522, Val Loss: 3.4983, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 70, Train Loss: 3.5521, Val Loss: 3.4982, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 80, Train Loss: 3.5522, Val Loss: 3.4978, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 90, Train Loss: 3.5523, Val Loss: 3.4982, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 0, Train Loss: 3.5536, Val Loss: 3.4977, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 10, Train Loss: 3.5522, Val Loss: 3.4976, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 20, Train Loss: 3.5520, Val Loss: 3.4974, Train Acc: 0.0308, Val Acc:0.0284
# Epoch 30, Train Loss: 3.5522, Val Loss: 3.4978, Train Acc: 0.0302, Val Acc:0.0306
# Epoch 40, Train Loss: 3.5522, Val Loss: 3.4979, Train Acc: 0.0312, Val Acc:0.0267
# Epoch 50, Train Loss: 3.5522, Val Loss: 3.4977, Train Acc: 0.0312, Val Acc:0.0267
# Epoch 60, Train Loss: 3.5521, Val Loss: 3.4977, Train Acc: 0.0307, Val Acc:0.0289
# Epoch 70, Train Loss: 3.5523, Val Loss: 3.4977, Train Acc: 0.0302, Val Acc:0.0306
# Epoch 80, Train Loss: 3.5524, Val Loss: 3.4978, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 90, Train Loss: 3.5521, Val Loss: 3.4978, Train Acc: 0.0305, Val Acc:0.0294
# → Moyenne CV accuracy pour lr=0.01, bs=256 : 0.0267
# Testing learning_rate=0.01, batch_size=512 ...
# Epoch 0, Train Loss: 3.6074, Val Loss: 3.4980, Train Acc: 0.0318, Val Acc:0.0243
# Epoch 10, Train Loss: 3.6063, Val Loss: 3.4984, Train Acc: 0.0318, Val Acc:0.0243
# Epoch 20, Train Loss: 3.6063, Val Loss: 3.4982, Train Acc: 0.0318, Val Acc:0.0243
# Epoch 30, Train Loss: 3.6063, Val Loss: 3.4980, Train Acc: 0.0312, Val Acc:0.0267
# Epoch 40, Train Loss: 3.6063, Val Loss: 3.4983, Train Acc: 0.0318, Val Acc:0.0243
# Epoch 50, Train Loss: 3.6063, Val Loss: 3.4980, Train Acc: 0.0307, Val Acc:0.0286
# Epoch 60, Train Loss: 3.6062, Val Loss: 3.4983, Train Acc: 0.0312, Val Acc:0.0267
# Epoch 70, Train Loss: 3.6065, Val Loss: 3.4988, Train Acc: 0.0318, Val Acc:0.0243
# Epoch 80, Train Loss: 3.6064, Val Loss: 3.4984, Train Acc: 0.0310, Val Acc:0.0274
# Epoch 90, Train Loss: 3.6064, Val Loss: 3.4984, Train Acc: 0.0318, Val Acc:0.0243
# Epoch 0, Train Loss: 3.6074, Val Loss: 3.4979, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 10, Train Loss: 3.6066, Val Loss: 3.4985, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 20, Train Loss: 3.6062, Val Loss: 3.4986, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 30, Train Loss: 3.6065, Val Loss: 3.4982, Train Acc: 0.0310, Val Acc:0.0274
# Epoch 40, Train Loss: 3.6064, Val Loss: 3.4986, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 50, Train Loss: 3.6064, Val Loss: 3.4984, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 60, Train Loss: 3.6063, Val Loss: 3.4982, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 70, Train Loss: 3.6063, Val Loss: 3.4986, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 80, Train Loss: 3.6064, Val Loss: 3.4985, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 90, Train Loss: 3.6064, Val Loss: 3.4979, Train Acc: 0.0320, Val Acc:0.0235
# Epoch 0, Train Loss: 3.6084, Val Loss: 3.4973, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 10, Train Loss: 3.6065, Val Loss: 3.4979, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 20, Train Loss: 3.6065, Val Loss: 3.4980, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 30, Train Loss: 3.6064, Val Loss: 3.4975, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 40, Train Loss: 3.6063, Val Loss: 3.4977, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 50, Train Loss: 3.6067, Val Loss: 3.4976, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 60, Train Loss: 3.6064, Val Loss: 3.4976, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 70, Train Loss: 3.6065, Val Loss: 3.4979, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 80, Train Loss: 3.6065, Val Loss: 3.4976, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 90, Train Loss: 3.6064, Val Loss: 3.4977, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 0, Train Loss: 3.6085, Val Loss: 3.4980, Train Acc: 0.0290, Val Acc:0.0282
# Epoch 10, Train Loss: 3.6064, Val Loss: 3.4984, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 20, Train Loss: 3.6065, Val Loss: 3.4980, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 30, Train Loss: 3.6065, Val Loss: 3.4986, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 40, Train Loss: 3.6063, Val Loss: 3.4980, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 50, Train Loss: 3.6063, Val Loss: 3.4980, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 60, Train Loss: 3.6065, Val Loss: 3.4981, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 70, Train Loss: 3.6064, Val Loss: 3.4978, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 80, Train Loss: 3.6063, Val Loss: 3.4982, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 90, Train Loss: 3.6065, Val Loss: 3.4983, Train Acc: 0.0315, Val Acc:0.0255
# Epoch 0, Train Loss: 3.6072, Val Loss: 3.4995, Train Acc: 0.0307, Val Acc:0.0289
# Epoch 10, Train Loss: 3.6064, Val Loss: 3.4979, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 20, Train Loss: 3.6063, Val Loss: 3.4976, Train Acc: 0.0307, Val Acc:0.0289
# Epoch 30, Train Loss: 3.6063, Val Loss: 3.4977, Train Acc: 0.0310, Val Acc:0.0277
# Epoch 40, Train Loss: 3.6062, Val Loss: 3.4981, Train Acc: 0.0312, Val Acc:0.0267
# Epoch 50, Train Loss: 3.6064, Val Loss: 3.4978, Train Acc: 0.0312, Val Acc:0.0267
# Epoch 60, Train Loss: 3.6063, Val Loss: 3.4976, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 70, Train Loss: 3.6064, Val Loss: 3.4975, Train Acc: 0.0302, Val Acc:0.0306
# Epoch 80, Train Loss: 3.6066, Val Loss: 3.4981, Train Acc: 0.0308, Val Acc:0.0284
# Epoch 90, Train Loss: 3.6065, Val Loss: 3.4978, Train Acc: 0.0312, Val Acc:0.0267
# → Moyenne CV accuracy pour lr=0.01, bs=512 : 0.0264
# Testing learning_rate=0.1, batch_size=128 ...
# Epoch 0, Train Loss: 4.1658, Val Loss: 3.5056, Train Acc: 0.0304, Val Acc:0.0301
# Epoch 10, Train Loss: 3.5351, Val Loss: 3.5146, Train Acc: 0.0310, Val Acc:0.0274
# Epoch 20, Train Loss: 3.5369, Val Loss: 3.5087, Train Acc: 0.0311, Val Acc:0.0269
# Epoch 30, Train Loss: 3.5355, Val Loss: 3.5051, Train Acc: 0.0318, Val Acc:0.0243
# Epoch 40, Train Loss: 3.5364, Val Loss: 3.5115, Train Acc: 0.0304, Val Acc:0.0299
# Epoch 50, Train Loss: 3.5362, Val Loss: 3.5071, Train Acc: 0.0312, Val Acc:0.0267
# Epoch 60, Train Loss: 3.5370, Val Loss: 3.5098, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 70, Train Loss: 3.5366, Val Loss: 3.5147, Train Acc: 0.0311, Val Acc:0.0269
# Epoch 80, Train Loss: 3.5364, Val Loss: 3.5097, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 90, Train Loss: 3.5370, Val Loss: 3.5056, Train Acc: 0.0294, Val Acc:0.0340
# Epoch 0, Train Loss: 4.0165, Val Loss: 3.5052, Train Acc: 0.0305, Val Acc:0.0294
# Epoch 10, Train Loss: 3.5376, Val Loss: 3.5087, Train Acc: 0.0302, Val Acc:0.0308
# Epoch 20, Train Loss: 3.5352, Val Loss: 3.5090, Train Acc: 0.0299, Val Acc:0.0318
# Epoch 30, Train Loss: 3.5367, Val Loss: 3.5117, Train Acc: 0.0299, Val Acc:0.0318
# Epoch 40, Train Loss: 3.5333, Val Loss: 3.5074, Train Acc: 0.0300, Val Acc:0.0316
# Epoch 50, Train Loss: 3.5353, Val Loss: 3.5061, Train Acc: 0.0304, Val Acc:0.0301
# Epoch 60, Train Loss: 3.5382, Val Loss: 3.5044, Train Acc: 0.0304, Val Acc:0.0301
# Epoch 70, Train Loss: 3.5359, Val Loss: 3.5041, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 80, Train Loss: 3.5378, Val Loss: 3.5109, Train Acc: 0.0310, Val Acc:0.0274
# Epoch 90, Train Loss: 3.5363, Val Loss: 3.5144, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 0, Train Loss: 4.4470, Val Loss: 3.5064, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 10, Train Loss: 3.5347, Val Loss: 3.5063, Train Acc: 0.0303, Val Acc:0.0304
# Epoch 20, Train Loss: 3.5373, Val Loss: 3.5133, Train Acc: 0.0306, Val Acc:0.0291
# Epoch 30, Train Loss: 3.5373, Val Loss: 3.5095, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 40, Train Loss: 3.5368, Val Loss: 3.5082, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 50, Train Loss: 3.5357, Val Loss: 3.5051, Train Acc: 0.0300, Val Acc:0.0316
# Epoch 60, Train Loss: 3.5366, Val Loss: 3.5088, Train Acc: 0.0304, Val Acc:0.0299
# Epoch 70, Train Loss: 3.5384, Val Loss: 3.5048, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 80, Train Loss: 3.5372, Val Loss: 3.5079, Train Acc: 0.0303, Val Acc:0.0304
# Epoch 90, Train Loss: 3.5361, Val Loss: 3.5085, Train Acc: 0.0303, Val Acc:0.0304
# Epoch 0, Train Loss: 4.2005, Val Loss: 3.5034, Train Acc: 0.0304, Val Acc:0.0301
# Epoch 10, Train Loss: 3.5369, Val Loss: 3.5059, Train Acc: 0.0305, Val Acc:0.0294
# Epoch 20, Train Loss: 3.5377, Val Loss: 3.5078, Train Acc: 0.0301, Val Acc:0.0311
# Epoch 30, Train Loss: 3.5380, Val Loss: 3.5095, Train Acc: 0.0292, Val Acc:0.0347
# Epoch 40, Train Loss: 3.5390, Val Loss: 3.5072, Train Acc: 0.0296, Val Acc:0.0330
# Epoch 50, Train Loss: 3.5363, Val Loss: 3.5101, Train Acc: 0.0310, Val Acc:0.0277
# Epoch 60, Train Loss: 3.5368, Val Loss: 3.5097, Train Acc: 0.0303, Val Acc:0.0304
# Epoch 70, Train Loss: 3.5368, Val Loss: 3.5164, Train Acc: 0.0308, Val Acc:0.0284
# Epoch 80, Train Loss: 3.5378, Val Loss: 3.5099, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 90, Train Loss: 3.5372, Val Loss: 3.5067, Train Acc: 0.0301, Val Acc:0.0311
# Epoch 0, Train Loss: 4.0667, Val Loss: 3.5085, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 10, Train Loss: 3.5380, Val Loss: 3.5058, Train Acc: 0.0312, Val Acc:0.0267
# Epoch 20, Train Loss: 3.5367, Val Loss: 3.5070, Train Acc: 0.0307, Val Acc:0.0289
# Epoch 30, Train Loss: 3.5356, Val Loss: 3.5062, Train Acc: 0.0303, Val Acc:0.0304
# Epoch 40, Train Loss: 3.5356, Val Loss: 3.5065, Train Acc: 0.0305, Val Acc:0.0294
# Epoch 50, Train Loss: 3.5362, Val Loss: 3.5096, Train Acc: 0.0304, Val Acc:0.0301
# Epoch 60, Train Loss: 3.5364, Val Loss: 3.5047, Train Acc: 0.0307, Val Acc:0.0287
# Epoch 70, Train Loss: 3.5383, Val Loss: 3.5173, Train Acc: 0.0307, Val Acc:0.0289
# Epoch 80, Train Loss: 3.5380, Val Loss: 3.5074, Train Acc: 0.0307, Val Acc:0.0287
# Epoch 90, Train Loss: 3.5365, Val Loss: 3.5090, Train Acc: 0.0307, Val Acc:0.0289
# → Moyenne CV accuracy pour lr=0.1, bs=128 : 0.0294
# Testing learning_rate=0.1, batch_size=256 ...
# Epoch 0, Train Loss: 5.1035, Val Loss: 3.5094, Train Acc: 0.0302, Val Acc:0.0306
# Epoch 10, Train Loss: 3.5583, Val Loss: 3.5058, Train Acc: 0.0310, Val Acc:0.0274
# Epoch 20, Train Loss: 3.5603, Val Loss: 3.5092, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 30, Train Loss: 3.5589, Val Loss: 3.5041, Train Acc: 0.0304, Val Acc:0.0301
# Epoch 40, Train Loss: 3.5595, Val Loss: 3.5063, Train Acc: 0.0298, Val Acc:0.0323
# Epoch 50, Train Loss: 3.5599, Val Loss: 3.5088, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 60, Train Loss: 3.5596, Val Loss: 3.5055, Train Acc: 0.0304, Val Acc:0.0301
# Epoch 70, Train Loss: 3.5617, Val Loss: 3.5071, Train Acc: 0.0299, Val Acc:0.0318
# Epoch 80, Train Loss: 3.5599, Val Loss: 3.5038, Train Acc: 0.0304, Val Acc:0.0299
# Epoch 90, Train Loss: 3.5609, Val Loss: 3.5039, Train Acc: 0.0294, Val Acc:0.0340
# Epoch 0, Train Loss: 4.5640, Val Loss: 3.5045, Train Acc: 0.0305, Val Acc:0.0294
# Epoch 10, Train Loss: 3.5609, Val Loss: 3.5020, Train Acc: 0.0299, Val Acc:0.0320
# Epoch 20, Train Loss: 3.5600, Val Loss: 3.5026, Train Acc: 0.0299, Val Acc:0.0320
# Epoch 30, Train Loss: 3.5615, Val Loss: 3.5048, Train Acc: 0.0300, Val Acc:0.0316
# Epoch 40, Train Loss: 3.5591, Val Loss: 3.5014, Train Acc: 0.0291, Val Acc:0.0352
# Epoch 50, Train Loss: 3.5589, Val Loss: 3.5025, Train Acc: 0.0299, Val Acc:0.0318
# Epoch 60, Train Loss: 3.5598, Val Loss: 3.5066, Train Acc: 0.0302, Val Acc:0.0308
# Epoch 70, Train Loss: 3.5602, Val Loss: 3.5063, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 80, Train Loss: 3.5591, Val Loss: 3.5056, Train Acc: 0.0310, Val Acc:0.0274
# Epoch 90, Train Loss: 3.5595, Val Loss: 3.5033, Train Acc: 0.0307, Val Acc:0.0286
# Epoch 0, Train Loss: 4.9118, Val Loss: 3.5014, Train Acc: 0.0303, Val Acc:0.0304
# Epoch 10, Train Loss: 3.5589, Val Loss: 3.5033, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 20, Train Loss: 3.5608, Val Loss: 3.5044, Train Acc: 0.0306, Val Acc:0.0291
# Epoch 30, Train Loss: 3.5604, Val Loss: 3.5046, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 40, Train Loss: 3.5591, Val Loss: 3.5077, Train Acc: 0.0304, Val Acc:0.0299
# Epoch 50, Train Loss: 3.5609, Val Loss: 3.5064, Train Acc: 0.0296, Val Acc:0.0330
# Epoch 60, Train Loss: 3.5604, Val Loss: 3.5047, Train Acc: 0.0304, Val Acc:0.0301
# Epoch 70, Train Loss: 3.5625, Val Loss: 3.5030, Train Acc: 0.0303, Val Acc:0.0304
# Epoch 80, Train Loss: 3.5613, Val Loss: 3.5036, Train Acc: 0.0306, Val Acc:0.0291
# Epoch 90, Train Loss: 3.5598, Val Loss: 3.5068, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 0, Train Loss: 4.9066, Val Loss: 3.5009, Train Acc: 0.0315, Val Acc:0.0255
# Epoch 10, Train Loss: 3.5594, Val Loss: 3.5026, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 20, Train Loss: 3.5604, Val Loss: 3.5027, Train Acc: 0.0304, Val Acc:0.0299
# Epoch 30, Train Loss: 3.5609, Val Loss: 3.5005, Train Acc: 0.0292, Val Acc:0.0347
# Epoch 40, Train Loss: 3.5610, Val Loss: 3.5050, Train Acc: 0.0315, Val Acc:0.0255
# Epoch 50, Train Loss: 3.5593, Val Loss: 3.5066, Train Acc: 0.0310, Val Acc:0.0277
# Epoch 60, Train Loss: 3.5594, Val Loss: 3.5083, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 70, Train Loss: 3.5604, Val Loss: 3.5055, Train Acc: 0.0304, Val Acc:0.0299
# Epoch 80, Train Loss: 3.5600, Val Loss: 3.5059, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 90, Train Loss: 3.5619, Val Loss: 3.5008, Train Acc: 0.0300, Val Acc:0.0316
# Epoch 0, Train Loss: 4.6367, Val Loss: 3.5075, Train Acc: 0.0307, Val Acc:0.0289
# Epoch 10, Train Loss: 3.5601, Val Loss: 3.5028, Train Acc: 0.0307, Val Acc:0.0289
# Epoch 20, Train Loss: 3.5596, Val Loss: 3.5056, Train Acc: 0.0304, Val Acc:0.0301
# Epoch 30, Train Loss: 3.5598, Val Loss: 3.5069, Train Acc: 0.0303, Val Acc:0.0304
# Epoch 40, Train Loss: 3.5597, Val Loss: 3.5035, Train Acc: 0.0305, Val Acc:0.0294
# Epoch 50, Train Loss: 3.5606, Val Loss: 3.5027, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 60, Train Loss: 3.5596, Val Loss: 3.5052, Train Acc: 0.0307, Val Acc:0.0287
# Epoch 70, Train Loss: 3.5608, Val Loss: 3.5079, Train Acc: 0.0308, Val Acc:0.0284
# Epoch 80, Train Loss: 3.5600, Val Loss: 3.5060, Train Acc: 0.0303, Val Acc:0.0304
# Epoch 90, Train Loss: 3.5586, Val Loss: 3.5062, Train Acc: 0.0304, Val Acc:0.0301
# → Moyenne CV accuracy pour lr=0.1, bs=256 : 0.0295
# Testing learning_rate=0.1, batch_size=512 ...
# Epoch 0, Train Loss: 7.1080, Val Loss: 3.5165, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 10, Train Loss: 3.6099, Val Loss: 3.4980, Train Acc: 0.0304, Val Acc:0.0299
# Epoch 20, Train Loss: 3.6107, Val Loss: 3.5028, Train Acc: 0.0304, Val Acc:0.0299
# Epoch 30, Train Loss: 3.6118, Val Loss: 3.5015, Train Acc: 0.0300, Val Acc:0.0316
# Epoch 40, Train Loss: 3.6119, Val Loss: 3.5034, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 50, Train Loss: 3.6115, Val Loss: 3.5035, Train Acc: 0.0304, Val Acc:0.0299
# Epoch 60, Train Loss: 3.6115, Val Loss: 3.5013, Train Acc: 0.0304, Val Acc:0.0301
# Epoch 70, Train Loss: 3.6129, Val Loss: 3.5039, Train Acc: 0.0311, Val Acc:0.0269
# Epoch 80, Train Loss: 3.6135, Val Loss: 3.5050, Train Acc: 0.0307, Val Acc:0.0289
# Epoch 90, Train Loss: 3.6118, Val Loss: 3.5026, Train Acc: 0.0312, Val Acc:0.0267
# Epoch 0, Train Loss: 7.0993, Val Loss: 3.5232, Train Acc: 0.0305, Val Acc:0.0294
# Epoch 10, Train Loss: 3.6106, Val Loss: 3.5016, Train Acc: 0.0291, Val Acc:0.0352
# Epoch 20, Train Loss: 3.6116, Val Loss: 3.4999, Train Acc: 0.0310, Val Acc:0.0274
# Epoch 30, Train Loss: 3.6114, Val Loss: 3.5037, Train Acc: 0.0300, Val Acc:0.0316
# Epoch 40, Train Loss: 3.6121, Val Loss: 3.4976, Train Acc: 0.0291, Val Acc:0.0352
# Epoch 50, Train Loss: 3.6119, Val Loss: 3.5006, Train Acc: 0.0299, Val Acc:0.0318
# Epoch 60, Train Loss: 3.6119, Val Loss: 3.5060, Train Acc: 0.0310, Val Acc:0.0274
# Epoch 70, Train Loss: 3.6116, Val Loss: 3.5031, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 80, Train Loss: 3.6112, Val Loss: 3.5068, Train Acc: 0.0302, Val Acc:0.0306
# Epoch 90, Train Loss: 3.6122, Val Loss: 3.5041, Train Acc: 0.0307, Val Acc:0.0286
# Epoch 0, Train Loss: 6.0946, Val Loss: 3.5160, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 10, Train Loss: 3.6124, Val Loss: 3.5023, Train Acc: 0.0311, Val Acc:0.0270
# Epoch 20, Train Loss: 3.6118, Val Loss: 3.4979, Train Acc: 0.0297, Val Acc:0.0325
# Epoch 30, Train Loss: 3.6121, Val Loss: 3.5016, Train Acc: 0.0300, Val Acc:0.0316
# Epoch 40, Train Loss: 3.6110, Val Loss: 3.5042, Train Acc: 0.0305, Val Acc:0.0294
# Epoch 50, Train Loss: 3.6136, Val Loss: 3.5031, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 60, Train Loss: 3.6124, Val Loss: 3.5016, Train Acc: 0.0306, Val Acc:0.0291
# Epoch 70, Train Loss: 3.6129, Val Loss: 3.5031, Train Acc: 0.0308, Val Acc:0.0282
# Epoch 80, Train Loss: 3.6125, Val Loss: 3.5024, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 90, Train Loss: 3.6126, Val Loss: 3.5041, Train Acc: 0.0311, Val Acc:0.0272
# Epoch 0, Train Loss: 6.0173, Val Loss: 3.5094, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 10, Train Loss: 3.6110, Val Loss: 3.4999, Train Acc: 0.0305, Val Acc:0.0294
# Epoch 20, Train Loss: 3.6119, Val Loss: 3.5004, Train Acc: 0.0304, Val Acc:0.0301
# Epoch 30, Train Loss: 3.6126, Val Loss: 3.4998, Train Acc: 0.0303, Val Acc:0.0304
# Epoch 40, Train Loss: 3.6133, Val Loss: 3.5044, Train Acc: 0.0305, Val Acc:0.0296
# Epoch 50, Train Loss: 3.6112, Val Loss: 3.5048, Train Acc: 0.0305, Val Acc:0.0294
# Epoch 60, Train Loss: 3.6114, Val Loss: 3.5076, Train Acc: 0.0317, Val Acc:0.0248
# Epoch 70, Train Loss: 3.6106, Val Loss: 3.5035, Train Acc: 0.0300, Val Acc:0.0316
# Epoch 80, Train Loss: 3.6124, Val Loss: 3.5029, Train Acc: 0.0304, Val Acc:0.0299
# Epoch 90, Train Loss: 3.6124, Val Loss: 3.4999, Train Acc: 0.0302, Val Acc:0.0308
# Epoch 0, Train Loss: 6.3981, Val Loss: 3.5220, Train Acc: 0.0309, Val Acc:0.0279
# Epoch 10, Train Loss: 3.6111, Val Loss: 3.5000, Train Acc: 0.0298, Val Acc:0.0323
# Epoch 20, Train Loss: 3.6103, Val Loss: 3.5005, Train Acc: 0.0304, Val Acc:0.0301
# Epoch 30, Train Loss: 3.6117, Val Loss: 3.5018, Train Acc: 0.0310, Val Acc:0.0277
# Epoch 40, Train Loss: 3.6123, Val Loss: 3.5032, Train Acc: 0.0305, Val Acc:0.0294
# Epoch 50, Train Loss: 3.6120, Val Loss: 3.4999, Train Acc: 0.0307, Val Acc:0.0289
# Epoch 60, Train Loss: 3.6106, Val Loss: 3.5024, Train Acc: 0.0303, Val Acc:0.0304
# Epoch 70, Train Loss: 3.6132, Val Loss: 3.5043, Train Acc: 0.0306, Val Acc:0.0291
# Epoch 80, Train Loss: 3.6127, Val Loss: 3.5023, Train Acc: 0.0304, Val Acc:0.0301
# Epoch 90, Train Loss: 3.6115, Val Loss: 3.5014, Train Acc: 0.0307, Val Acc:0.0287
# → Moyenne CV accuracy pour lr=0.1, bs=512 : 0.0310
#
# Meilleure combinaison : learning_rate=0.001, batch_size=128 avec CV accuracy=0.8010
# Epoch 0, Train Loss: 3.5187, Val Loss: 3.4964, Train Acc: 0.0313, Val Acc:0.0313
# Epoch 10, Train Loss: 2.3794, Val Loss: 2.2478, Train Acc: 0.2615, Val Acc:0.2615
# Epoch 20, Train Loss: 1.5342, Val Loss: 1.4844, Train Acc: 0.5267, Val Acc:0.5267
# Epoch 30, Train Loss: 1.3581, Val Loss: 1.3288, Train Acc: 0.5867, Val Acc:0.5867
# Epoch 40, Train Loss: 1.2696, Val Loss: 1.2491, Train Acc: 0.6115, Val Acc:0.6115
# Epoch 50, Train Loss: 1.0443, Val Loss: 1.1130, Train Acc: 0.6373, Val Acc:0.6373
# Epoch 60, Train Loss: 0.9439, Val Loss: 0.9505, Train Acc: 0.7115, Val Acc:0.7115
# Epoch 70, Train Loss: 0.8606, Val Loss: 0.8447, Train Acc: 0.7534, Val Acc:0.7534
# Epoch 80, Train Loss: 0.7533, Val Loss: 0.7199, Train Acc: 0.7951, Val Acc:0.7951
# Epoch 90, Train Loss: 0.6410, Val Loss: 0.6745, Train Acc: 0.8007, Val Acc:0.8007
#
# Rapport de classification (Test set) avec la meilleure combinaison :
#               precision    recall  f1-score   support
#
#           ya       0.97      0.99      0.98       156
#          yab       0.92      0.87      0.89       156
#         yach       0.88      0.78      0.83       156
#          yad       0.84      0.81      0.82       156
#         yadd       0.85      0.92      0.88       156
#          yae       0.75      0.83      0.78       156
#          yaf       0.85      0.81      0.83       156
#          yag       0.95      0.81      0.87       156
#         yagh       0.72      0.85      0.78       156
#         yagw       0.77      0.72      0.75       156
#          yah       0.84      0.88      0.86       156
#         yahh       0.88      0.74      0.80       156
#          yaj       0.92      0.88      0.90       156
#          yak       0.89      0.61      0.72       156
#         yakw       0.92      0.76      0.83       156
#          yal       0.79      0.85      0.82       156
#          yam       0.80      0.94      0.86       156
#          yan       0.90      0.78      0.83       156
#          yaq       0.86      0.85      0.85       156
#          yar       0.84      0.97      0.90       156
#         yarr       0.89      0.81      0.85       156
#          yas       0.76      0.96      0.85       156
#         yass       0.72      0.83      0.77       156
#          yat       0.81      0.93      0.87       156
#         yatt       0.86      0.78      0.82       156
#          yaw       0.92      0.85      0.88       156
#          yax       0.90      0.92      0.91       156
#          yay       0.78      0.88      0.83       156
#          yaz       0.88      0.75      0.81       156
#         yazz       0.97      0.93      0.95       156
#          yey       0.73      0.73      0.73       156
#           yi       0.60      0.80      0.68       156
#           yu       0.61      0.55      0.58       156
#
#     accuracy                           0.83      5148
#    macro avg       0.84      0.83      0.83      5148
# weighted avg       0.84      0.83      0.83      5148
